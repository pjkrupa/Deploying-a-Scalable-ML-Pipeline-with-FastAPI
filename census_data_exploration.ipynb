# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/original/census.csv')
df.head()
# Out:
#    age         workclass   fnlgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
df['salary'].value_counts()
# Out:
# salary
# <=50K    24720
# >50K      7841
# Name: count, dtype: int64

# %%
df['salary'] = df['salary'].map(lambda x: 1 if x=='>50K' else 0)

# %%
df['salary'].value_counts()
# Out:
# salary
# 0    24720
# 1     7841
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlgt           32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                 age         fnlgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df['salary'].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
df = df.map(lambda x: x.strip().lower() if isinstance(x, str) else x)

# %%
df['salary'] = df['salary'].map(lambda x: 1 if x=='>50K' else 0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlgt           32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  int64
# dtypes: int64(7), object(8)
# memory usage: 3.7+ MB

# %%
df.sample(15)
# Out:
#        age         workclass   fnlgt     education  education-num  \
# 6628    49           private  123584          11th              7
# 13367   52           private  204584     bachelors             13
# 29063   45  self-emp-not-inc  162923       hs-grad              9
# 7606    43  self-emp-not-inc  154785     bachelors             13
# 8713    55           private  113912     assoc-voc             11
# 29040   34                 ?  222548  some-college             10
# 23994   43           private  184321          10th              6
# 22501   20           private  173736           9th              5
# 26054   43           private  191765       hs-grad              9
# 22423   17           private  566049          10th              6
# 1252    30           private  283767       hs-grad              9
# 11701   67      self-emp-inc  411007       hs-grad              9
# 30333   30         local-gov  289442       hs-grad              9
# 18783   32  self-emp-not-inc   27939  some-college             10
# 13440   22           private  183257  some-college             10
#
#               marital-status         occupation   relationship  \
# 6628      married-civ-spouse   transport-moving        husband
# 13367  married-spouse-absent    exec-managerial  not-in-family
# 29063     married-civ-spouse       craft-repair        husband
# 7606      married-civ-spouse  machine-op-inspct           wife
# 8713      married-civ-spouse     prof-specialty           wife
# 29040     married-civ-spouse                  ?           wife
# 23994     married-civ-spouse  machine-op-inspct        husband
# 22501          never-married  machine-op-inspct      own-child
# 26054               divorced       tech-support      unmarried
# 22423          never-married      other-service      own-child
# 1252      married-civ-spouse       adm-clerical        husband
# 11701                widowed    exec-managerial  not-in-family
# 30333          never-married    protective-serv  not-in-family
# 18783     married-civ-spouse              sales        husband
# 13440          never-married              sales      own-child
#
#                      race     sex  capital-gain  capital-loss  hours-per-week  \
# 6628                white    male             0             0              75
# 13367               white  female             0             0              42
# 29063               white    male             0             0              60
# 7606   asian-pac-islander  female             0             0              80
# 8713                white  female             0             0              20
# 29040               white  female             0             0               4
# 23994               black    male             0          1887              40
# 22501               white    male             0             0              40
# 26054               black  female             0             0              35
# 22423               white    male             0             0               8
# 1252                white    male             0             0              40
# 11701               white  female         15831             0              40
# 30333               white    male             0             0              40
# 18783  amer-indian-eskimo    male             0             0              60
# 13440               black  female             0             0              20
#
#       native-country  salary
# 6628   united-states       0
# 13367  united-states       0
# 29063  united-states       0
# 7606        thailand       0
# 8713   united-states       0
# 29040  united-states       0
# 23994  united-states       0
# 22501  united-states       0
# 26054  united-states       0
# 22423  united-states       0
# 1252               ?       0
# 11701  united-states       0
# 30333  united-states       0
# 18783  united-states       0
# 13440  united-states       0

# %%
df.to_csv('data/census.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlgt           32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  int64
# dtypes: int64(7), object(8)
# memory usage: 3.7+ MB
